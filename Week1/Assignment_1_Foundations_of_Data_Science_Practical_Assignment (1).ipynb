# %% [markdown]
# # **Task 1: Introduction to Data Science**

# %% [markdown]
# **Data Science Overview**
#
# Data science is a science concerned with studying data by applying mathematical and statistical concepts to the data, which allows us to analyze it and derive relationships and ideas from it that help solve problems or avoid future problems. Data science is used in many fields around us, such as advertisements on e-mails or initially setting prices on websites. It is also used in modern phones, medicine, and in many fields.

# %% [markdown]
# **Setting up the Environment**

# %%
# !pip install numpy pandas seaborn

# %% [markdown]
# **Loading and Displaying Data**
#
# Data Link: https://www.kaggle.com/datasets/carlolepelaars/toy-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV data using pandas
df = pd.read_csv("/content/toy_dataset.csv")

# Display the first 5 entries
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %% [markdown]
# # **Task 2: Core Concepts and Principles**

# %% [markdown]
# **Data Types and Structures**

# %%
x = 5 # integer variable
y = 6.5 # float variable
z = "Omar" # string variable

# %%
# Working with numerical variables

print(x + y) # Addition
print(x - y) # Subtraction
print(x * y) # Multiplication
print(x / y) # Division
print(x // y) # Integer division
print(x % y) # Modulus (remainder)


# Working with character variables
print(z*x) # string multiplaction
print(z[0]) # get the first letter ---> string slicing (+ve index)
print(z[-1]) # get the last letter ---> string slicing (-ve index)
print(z[:3]) # get the range of character from the begining to the (3-1) poisiton [inclusive:exclusive]
# Out:
# 11.5
# -1.5
# 32.5
# 0.7692307692307693
# 0.0
# 5.0
# OmarOmarOmarOmarOmar
# O
# r
# Oma

# %% [markdown]
# **Data Manipulation**

# %%
# Dimension of the data
df.shape

print(f'the number of rows {df.shape[0]}\nthe number of columns {df.shape[1]} ')
# Out:
# the number of rows 150000
# the number of columns 6

# %%
# Checking the null values
df.isnull().sum()
# Out:
# Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %%
# Correlation matrix
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Number       Age    Income
# Number  1.000000 -0.003448  0.410460
# Age    -0.003448  1.000000 -0.001318
# Income  0.410460 -0.001318  1.000000

# %%
# datatypes and information about columns and entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Number   150000 non-null  int64
#  1   City     150000 non-null  object
#  2   Gender   150000 non-null  object
#  3   Age      150000 non-null  int64
#  4   Income   150000 non-null  float64
#  5   Illness  150000 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 6.9+ MB

# %%
# Statistical Info
df.describe()
# Out:
#               Number            Age         Income
# count  150000.000000  150000.000000  150000.000000
# mean    75000.500000      44.950200   91252.798273
# std     43301.414527      11.572486   24989.500948
# min         1.000000      25.000000    -654.000000
# 25%     37500.750000      35.000000   80867.750000
# 50%     75000.500000      45.000000   93655.000000
# 75%    112500.250000      55.000000  104519.000000
# max    150000.000000      65.000000  177157.000000

# %%
# Column names
df.columns
# Out:
# Index(['Number', 'City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %%
# Dropping the Number column
df.drop("Number", axis=1, inplace = True)
df.head()
# Out:
#      City Gender  Age   Income Illness
# 0  Dallas   Male   41  40367.0      No
# 1  Dallas   Male   54  45084.0      No
# 2  Dallas   Male   42  52483.0      No
# 3  Dallas   Male   40  40941.0      No
# 4  Dallas   Male   46  50289.0      No

# %%
# prompt: Using dataframe df: create crosstable

# Cross table
cross_table = pd.crosstab(index=df['City'], columns=df['Gender'])
print("Cross table:")
cross_table
# Out:
# Cross table:
# Gender           Female   Male
# City
# Austin             5385   6907
# Boston             3715   4586
# Dallas             8705  11002
# Los Angeles       14285  17888
# Mountain View      6276   7943
# New York City     22172  28135
# San Diego          2098   2783
# Washington D.C.    3564   4556

# %% [markdown]
# From the above table we can see the number of males is higher than females

# %%
# Pivot table
pivot_table = df.pivot_table(index='City', columns=['Gender', 'Illness'], values='Income', aggfunc='mean')
print("\nPivot table:")
pivot_table
# Out:
# Pivot table:
# Gender                  Female                          Male
# Illness                     No            Yes             No            Yes
# City
# Austin            84943.528165   85133.405093   94463.185999   93998.666667
# Boston            85958.026377   86208.343234   96022.932667   96606.261097
# Dallas            39608.374515   39536.553672   49718.603149   49764.566851
# Los Angeles       89757.601477   89445.666667   99701.155869   99454.835800
# Mountain View    129519.701477  129001.310940  139518.930552  139344.750381
# New York City     91167.732951   91210.229296  101307.878520  101685.501336
# San Diego         95250.140874   96123.496732  104785.571991  105633.668050
# Washington D.C.   65413.787111   65848.558621   75329.127573   75306.825397

# %% [markdown]
# From the above table we can see the average illness of males is higher than females

# %%
# Filtiring all males
df[df['Gender'] == 'Male']
# Out:
#           City Gender  Age    Income Illness
# 0       Dallas   Male   41   40367.0      No
# 1       Dallas   Male   54   45084.0      No
# 2       Dallas   Male   42   52483.0      No
# 3       Dallas   Male   40   40941.0      No
# 4       Dallas   Male   46   50289.0      No
# ...        ...    ...  ...       ...     ...
# 149993  Austin   Male   64   89906.0      No
# 149995  Austin   Male   48   93669.0      No
# 149996  Austin   Male   25   96748.0      No
# 149997  Austin   Male   26  111885.0      No
# 149998  Austin   Male   25  111878.0      No
#
# [83800 rows x 5 columns]

# %%
# Filtiring all females
df[df['Gender'] == 'Female']
# Out:
#           City  Gender  Age    Income Illness
# 5       Dallas  Female   36   50786.0      No
# 6       Dallas  Female   32   33155.0      No
# 9       Dallas  Female   30   50082.0      No
# 10      Dallas  Female   48   41524.0     Yes
# 13      Dallas  Female   42   50894.0      No
# ...        ...     ...  ...       ...     ...
# 149987  Austin  Female   55   62501.0      No
# 149988  Austin  Female   26   77823.0      No
# 149990  Austin  Female   26   82163.0      No
# 149994  Austin  Female   37  106097.0      No
# 149999  Austin  Female   37   87251.0      No
#
# [66200 rows x 5 columns]

# %%
# Group by summarisation
df.groupby(['City', 'Gender']).agg({'Income': 'mean', 'Age': 'mean'}).reset_index()
# Out:
#                City  Gender         Income        Age
# 0            Austin  Female   84958.760631  44.505478
# 1            Austin    Male   94424.246272  44.764876
# 2            Boston  Female   85978.442530  45.219112
# 3            Boston    Male   96071.649368  45.180549
# 4            Dallas  Female   39602.533142  45.141987
# 5            Dallas    Male   49722.384021  44.992910
# 6       Los Angeles  Female   89732.511306  44.963668
# 7       Los Angeles    Male   99681.616055  45.018392
# 8     Mountain View  Female  129476.667463  45.011791
# 9     Mountain View    Male  139504.523354  44.977716
# 10    New York City  Female   91171.135035  45.037976
# 11    New York City    Male  101338.023920  44.830816
# 12        San Diego  Female   95313.831745  45.093422
# 13        San Diego    Male  104859.014732  44.868487
# 14  Washington D.C.  Female   65449.164141  44.964085
# 15  Washington D.C.    Male   75327.277217  44.676471

# %% [markdown]
# **Feature Engineering**

# %%
# Define bins for income
income_bins = [0, 50000, 60000, 70000, float('inf')]  # Define the income bins

# Create a new column 'bins' based on 'Income'
df['bins'] = pd.cut(df['Income'], bins=income_bins, labels=['<50k', '50k-60k', '60k-70k', '>70k'])

df
# Out:
#           City  Gender  Age    Income Illness  Income_Normalized  High_Income  \
# 0       Dallas    Male   41   40367.0      No           0.230700            0
# 1       Dallas    Male   54   45084.0      No           0.257228            0
# 2       Dallas    Male   42   52483.0      No           0.298840            1
# 3       Dallas    Male   40   40941.0      No           0.233928            0
# 4       Dallas    Male   46   50289.0      No           0.286501            1
# ...        ...     ...  ...       ...     ...                ...          ...
# 149995  Austin    Male   48   93669.0      No           0.530468            1
# 149996  Austin    Male   25   96748.0      No           0.547784            1
# 149997  Austin    Male   26  111885.0      No           0.632914            1
# 149998  Austin    Male   25  111878.0      No           0.632874            1
# 149999  Austin  Female   37   87251.0      No           0.494373            1
#
#            bins
# ...

# %%
# Normalization (Min-Max Scaling)
df['Income_Normalized'] = (df['Income'] - df['Income'].min()) / (df['Income'].max() - df['Income'].min())

# Binarization
income_threshold = 50000
df['High_Income'] = (df['Income'] > income_threshold).astype(int)

df
# Out:
#           City  Gender  Age    Income Illness  Income_Normalized  High_Income
# 0       Dallas    Male   41   40367.0      No           0.230700            0
# 1       Dallas    Male   54   45084.0      No           0.257228            0
# 2       Dallas    Male   42   52483.0      No           0.298840            1
# 3       Dallas    Male   40   40941.0      No           0.233928            0
# 4       Dallas    Male   46   50289.0      No           0.286501            1
# ...        ...     ...  ...       ...     ...                ...          ...
# 149995  Austin    Male   48   93669.0      No           0.530468            1
# 149996  Austin    Male   25   96748.0      No           0.547784            1
# 149997  Austin    Male   26  111885.0      No           0.632914            1
# 149998  Austin    Male   25  111878.0      No           0.632874            1
# 149999  Austin  Female   37   87251.0      No           0.494373            1
#
# [150000 rows x 7 columns]

# %% [markdown]
# The bins here is just an indication of which category income will be.

# %% [markdown]
# # **Task 3: Statistical Analysis**

# %% [markdown]
# **Descriptive Statistics**

# %%
# Mean
for column in df._get_numeric_data().columns:
  print(f'The mean of {column} column is {df[column].mean()}')

print()

# Median
for column in df._get_numeric_data().columns:
  print(f'The median of {column} column is {df[column].median()}')

print()

# Standard Deviation
for column in df._get_numeric_data().columns:
  print(f'The mean of {column} column is {df[column].std()}')
# Out:
# The mean of Age column is 44.9502
# The mean of Income column is 91252.79827333333
# The mean of Income_Normalized column is 0.5168791484966248
# The mean of High_Income column is 0.9115866666666667
#
# The median of Age column is 45.0
# The median of Income column is 93655.0
# The median of Income_Normalized column is 0.5303890085540265
# The median of High_Income column is 1.0
#
# The mean of Age column is 11.572485735982024
# The mean of Income column is 24989.500948354904
# The mean of Income_Normalized column is 0.14053967948189316
# The mean of High_Income column is 0.2838960252191691

# %% [markdown]
# **Inferential Statistics**

# %% [markdown]
# the hypothesis is there is an affect of gender on income. Here's a formulated hypothesis:
#
#
# **Null Hypothesis (H0)**: There is no significant difference in the mean income between males and females.
#
#
# **Alternative Hypothesis (H1)**: There is a significant difference in the mean income between males and females.

# %%
from scipy.stats import ttest_ind

group1 = df[df['Gender'] == 'Male']['Income']
group2 = df[df['Gender'] == 'Female']['Income']

# Perform t-test
t_statistic, p_value = ttest_ind(group1, group2)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 78.5986737417554
# P-value: 0.0

# %% [markdown]
# where The t-statistic measures the difference between the means of the two groups (males and females) relative to the variation within the groups. A larger absolute value of the t-statistic indicates a greater difference between the means.
#
#
#
# Given the extremely low p-value (0.0), we reject the null hypothesis and conclude that there is a significant difference in the mean income between males and females. In other words, gender appears to have a significant impact on income levels in the sample data.

# %% [markdown]
# # **Task 4: Exploratory Data Analysis**

# %% [markdown]
# **Data Visualization**

# %%
cross_table = pd.crosstab(index=df['City'], columns=df['Gender'])

# Visualizations
# Bar plot for cross table
plt.figure(figsize=(12,8))
cross_table.plot(kind='bar')
plt.title('Cross Table - City vs Gender')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Males are dominant in all cities

# %%
pivot_table = df.pivot_table(index='City', columns='Gender', values='Income', aggfunc='mean')

# Heatmap for pivot table
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu")
plt.title('Pivot Table - Mean Income by City and Gender')
plt.xlabel('Gender')
plt.ylabel('City')
plt.show()

# %% [markdown]
# Mountain view has the hieghst income rate for both males and females where Dallas was the lowest

# %%
# Boxplot for Income Distribution by Gender
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Gender', y='Income')
plt.title('Income Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Income')
plt.show()

# %%
# Countplot for City and Gender
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='City', hue='Gender')
plt.title('Count of Individuals by City and Gender')
plt.xlabel('City')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.ylabel('Values')
plt.title('Boxplot to Catch Outliers')
plt.show()

# %%
# IQR technique

# Select only numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Calculate quartiles and IQR for numeric columns
Q1 = numeric_columns.quantile(0.25)
Q3 = numeric_columns.quantile(0.75)
IQR = Q3 - Q1

# Set a threshold for considering a point as an outlier
k = 1.5
outliers = ((numeric_columns < (Q1 - k * IQR)) | (numeric_columns > (Q3 + k * IQR))).any(axis=1)

# Display rows without outliers
df_outliers = df[~outliers]

# %%
print(f'The Number of original rows: {df.shape[0]}')
print(f'The Number of original columns: {df.shape[1]}')

print(f'\nThe Number of cleaned rows: {df_outliers.shape[0]}')
print(f'The Number of cleaned columns: {df_outliers.shape[1]}')

print(f'\nThe number of outliers records that dropped is: {df.shape[0] - df_outliers.shape[0]}')
# Out:
# The Number of original rows: 150000
# The Number of original columns: 8
#
# The Number of cleaned rows: 131972
# The Number of cleaned columns: 8
#
# The number of outliers records that dropped is: 18028

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_outliers)
plt.xticks(rotation=90)
plt.ylabel('Values')
plt.title('New Boxplot After Handeling Outliers')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Boxplot for the original DataFrame (df)
sns.boxplot(data=df, ax=axes[0])
axes[0].set(title='Original Data', ylabel='Value')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)  # Rotate x-axis labels

# Boxplot for the DataFrame without outliers (df_outliers)
sns.boxplot(data=df_outliers, ax=axes[1])
axes[1].set(title='Price variation based on destination city', ylabel='Value')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)  # Rotate x-axis labels

plt.suptitle('Outliers Comparison', fontsize=16)

plt.show()
# Out:
# <ipython-input-93-6b4a794f85be>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)  # Rotate x-axis labels
# <ipython-input-93-6b4a794f85be>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)  # Rotate x-axis labels

# %% [markdown]
# The difference is notable in using the IQR technique to handle outliers

# %%
# Correlation matrix
correlation_matrix = df.corr(numeric_only = True)

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# As we before done the feature engineering the new columns are positively correlated with the income column which means if the income goes up the high income will likely go and so on
